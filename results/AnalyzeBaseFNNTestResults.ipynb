# %%
import numpy as np
import scipy
from scipy.stats import sem, ttest_ind, ttest_rel, wilcoxon

# %% [markdown]
# #Baseline FCNN
#
# standardized labels
#
# WandB:
# https://wandb.ai/js-test-team/pcm-wurdinger-testset-OutputStd-3?workspace=user-wurdingerla

# %%
# BaseLine TestSet CI Scores
basline_ci = np.array([0.8735,
                       0.8723,
                       0.8753,
                       0.8735,
                       0.8724,
                       0.8744,
                       0.8743,
                       0.8766,
                       0.8738,
                       0.8788])

# %%
#Mean
baseline_ci_mean = np.mean(basline_ci)
print(f'BaseLine Mean: {baseline_ci_mean}')
#STD
baseline_ci_std = np.std(basline_ci)
print(f'PCM TEST STD. {baseline_ci_std}')
#Standarderror
baseline_ci_ste = sem(basline_ci)
print(f'PCM TEST STE: {baseline_ci_ste}')
# Out:
# BaseLine Mean: 0.8744900000000001
# PCM TEST STD. 0.0018796010214936702
# PCM TEST STE: 0.0006265336738312233

# %%
# BaseLine TestSet MSE Scores
basline_mse = np.array([0.1314,
                       0.1299,
                       0.1283,
                       0.1332,
                       0.1315,
                       0.1303,
                       0.1306,
                       0.1303,
                       0.1294,
                       0.131])

# %%
#Mean
baseline_mse_mean = np.mean(basline_mse)
print(f'BaseLine Mean: {baseline_mse_mean}')
#STD
baseline_mse_std = np.std(basline_mse)
print(f'PCM TEST STD. {baseline_mse_std}')
#Standarderror
baseline_mse_ste = sem(basline_mse)
print(f'PCM TEST STE: {baseline_mse_ste}')
# Out:
# BaseLine Mean: 0.13059
# PCM TEST STD. 0.0012557467897629732
# PCM TEST STE: 0.00041858226325432434

# %% [markdown]
# #Baseline FCNN - Error
#
# no standardized labels
#
# WandB:
# https://wandb.ai/js-test-team/pcm-wurdinger-testset-OutputStd-2

# %%
# BaseLine TestSet CI Scores
basline_ci_error = np.array([0.8745,
                       0.8769,
                       0.87,
                       0.8758,
                       0.8728,
                       0.8737,
                       0.8754,
                       0.8728,
                       0.875,
                       0.8714])

# %%
#Mean
baseline_ci_mean_error = np.mean(basline_ci_error)
print(f'BaseLine Mean: {baseline_ci_mean_error}')
#STD
baseline_ci_std_error = np.std(basline_ci_error)
print(f'PCM VAL STD. {baseline_ci_std_error}')
#Standarderror
baseline_ci_ste_error = sem(basline_ci_error)
print(f'PCM VAL STE: {baseline_ci_ste_error}')
# Out:
# BaseLine Mean: 0.8738300000000001
# PCM VAL STD. 0.0020075108966080427
# PCM VAL STE: 0.0006691702988693475

# %%
# BaseLine TestSet MSE Scores
basline_mse_error = np.array([0.09363,
                       0.09544,
                       0.09239,
                       0.09129,
                       0.09461,
                       0.09277,
                       0.09257,
                       0.09212,
                       0.09565,
                       0.09281])

# %%
#Mean
baseline_mse_mean_error = np.mean(basline_mse_error)
print(f'BaseLine_error Mean: {baseline_mse_mean_error}')
#STD
baseline_mse_std_error = np.std(basline_mse_error)
print(f'PCM_error TEST STD. {baseline_mse_std_error}')
#Standarderror
baseline_mse_ste_error = sem(basline_mse_error)
print(f'PCM_error TEST STE: {baseline_mse_ste_error}')
# Out:
# BaseLine Mean: 0.09332800000000001
# PCM VAL STD. 0.0013868583200889704
# PCM VAL STE: 0.00046228610669632345
